# %% [markdown]
# Install Anaconda
#
# Start jupyter lab
#
# Create a notebook that contains three cells.
#
# Make the first cell a markdown cell. In the first cell, use header 1 style to place a title for the document. In this same cell, use header 2 style to write your name
#
# Make the second cell a markdown cell. In this cell place a picture of your self and a brief bio (introduction).
#
# Make sure the third cell is a code cell. In this cell print the words Hello World to the screen using Python's print function.

# %% [markdown]
# # ICP01 Jupyter Install
# ## Simran Agichani

# %% [markdown]
# ![psprt size pic.jpeg](attachment:a3661c74-b31d-4200-8ac4-08685d414f34.jpeg)
#
# I hail from India's cleanest city Indore. I have completed my undergrad in Information Technology with a work experience of 2.5 years in TCS, Pune. I worked on data management platform for a german bank as my client. Apart from academics, I have joined the chess club and the latin dance club at USF as I love to play chess and dance.

# %%
print("Hello World")
# Out:
# Hello World
